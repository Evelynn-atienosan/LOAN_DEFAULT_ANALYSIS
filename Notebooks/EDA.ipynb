# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\hp\LOAN_DEFAULT_ANALYSIS\Cleaned_csv_file\Loan_default_clean.csv")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16200\2651651939.py:3: DtypeWarning: Columns (0: next_pymnt_d) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\hp\LOAN_DEFAULT_ANALYSIS\Cleaned_csv_file\Loan_default_clean.csv")

# %%
df.head(5)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       2500         2500           2500.0   36 months     13.56        84.92
# 1      30000        30000          30000.0   60 months     18.94       777.23
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3       4000         4000           4000.0   36 months     18.94       146.51
# 4      30000        30000          30000.0   60 months     16.14       731.78
#
#   grade sub_grade       emp_title emp_length  ... tax_liens  tot_hi_cred_lim  \
# 0     C        C1            Chef  10+ years  ...       0.0          60124.0
# 1     D        D2     Postmaster   10+ years  ...       0.0         372872.0
# 2     D        D1  Administrative    6 years  ...       0.0         136927.0
# 3     D        D2   IT Supervisor  10+ years  ...       0.0         385183.0
# 4     C        C4        Mechanic  10+ years  ...       0.0         157548.0
#
# ...

# %%
df.head(5)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       2500         2500           2500.0   36 months     13.56        84.92
# 1      30000        30000          30000.0   60 months     18.94       777.23
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3       4000         4000           4000.0   36 months     18.94       146.51
# 4      30000        30000          30000.0   60 months     16.14       731.78
#
#   grade sub_grade       emp_title emp_length  ... tax_liens  tot_hi_cred_lim  \
# 0     C        C1            Chef  10+ years  ...       0.0          60124.0
# 1     D        D2     Postmaster   10+ years  ...       0.0         372872.0
# 2     D        D1  Administrative    6 years  ...       0.0         136927.0
# 3     D        D2   IT Supervisor  10+ years  ...       0.0         385183.0
# 4     C        C4        Mechanic  10+ years  ...       0.0         157548.0
#
# ...

# %%
df.columns.tolist()
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'policy_code',
#  'application_type',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
# ...

# %%
df.dtypes
# Out:
# loan_amnt                 int64
# funded_amnt               int64
# funded_amnt_inv         float64
# term                        str
# int_rate                float64
#                          ...
# hardship_flag               str
# disbursement_method         str
# debt_settlement_flag        str
# is_joint_application      int64
# default_status              str
# Length: 105, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df["grade"].value_counts()
# Out:
# grade
# B    663557
# C    650053
# A    433027
# D    324424
# E    135639
# F     41800
# G     12168
# Name: count, dtype: int64

# %%
df["home_ownership"].value_counts()
# Out:
# home_ownership
# MORTGAGE    1111450
# RENT         894929
# OWN          253057
# ANY             996
# OTHER           182
# NONE             54
# Name: count, dtype: int64

# %%
df["verification_status"].value_counts()
# Out:
# verification_status
# Source Verified    886231
# Not Verified       744806
# Verified           629631
# Name: count, dtype: int64

# %%
df["term"].value_counts()
# Out:
# term
# 36 months    1609754
# 60 months     650914
# Name: count, dtype: int64

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid                                             1041952
# Current                                                 919695
# Charged Off                                             261655
# Late (31-120 days)                                       21897
# In Grace Period                                           8952
# Late (16-30 days)                                         3737
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     31
# Name: count, dtype: int64

# %% [markdown]
# Loan Status Distribution

# %%
df["loan_status"].value_counts().plot(
    kind="bar",
    figsize=(10,6),
    title="Loan Status Distribution"
)
# Out:
# <Axes: title={'center': 'Loan Status Distribution'}, xlabel='loan_status'>

# %% [markdown]
# Default status distribution

# %%
df["default_status"].value_counts()
# Out:
# default_status
# Did Not Default    1043940
# Outcome Unknown     954281
# Defaulted           262447
# Name: count, dtype: int64

# %%
df["default_status"].value_counts(normalize=True) * 100
# Out:
# default_status
# Did Not Default    46.178386
# Outcome Unknown    42.212346
# Defaulted          11.609268
# Name: proportion, dtype: float64

# %%
df["default_status"].value_counts().plot(
    kind="bar",
    figsize=(8,5),
    title="Loan Default Status"
)
# Out:
# <Axes: title={'center': 'Loan Default Status'}, xlabel='default_status'>

# %% [markdown]
# Loan Amount EDA

# %%
df["loan_amnt"].describe()
# Out:
# count    2.260668e+06
# mean     1.504693e+04
# std      9.190245e+03
# min      5.000000e+02
# 25%      8.000000e+03
# 50%      1.290000e+04
# 75%      2.000000e+04
# max      4.000000e+04
# Name: loan_amnt, dtype: float64

# %%
df["loan_amnt"].plot(
    kind="hist",
    bins=30,
    figsize=(10,6),
    title="Distribution of Loan Amount"
)
# Out:
# <Axes: title={'center': 'Distribution of Loan Amount'}, ylabel='Frequency'>

# %%
df.groupby(
    "default_status"
)["loan_amnt"].mean()
# Out:
# default_status
# Defaulted          15531.548179
# Did Not Default    14122.440274
# Outcome Unknown    15925.002594
# Name: loan_amnt, dtype: float64

# %% [markdown]
# Interest Rate EDA

# %%
df["int_rate"].value_counts()
# Out:
# int_rate
# 11.99    53869
# 5.32     47171
# 10.99    44165
# 13.99    43026
# 11.49    32009
#          ...
# 18.72        1
# 17.78        1
# 16.83        1
# 17.72        1
# 17.41        1
# Name: count, Length: 673, dtype: int64

# %%
df["int_rate"].plot(
    kind="hist",
    bins=30,
    figsize=(10,6),
    title="Interest Rate Distribution"
)
# Out:
# <Axes: title={'center': 'Interest Rate Distribution'}, ylabel='Frequency'>

# %%
df.groupby(
    "default_status"
)["int_rate"].mean()
# Out:
# default_status
# Defaulted          15.708974
# Did Not Default    12.643303
# Outcome Unknown    12.865295
# Name: int_rate, dtype: float64

# %% [markdown]
# Loan Grade EDA

# %%
df["grade"].value_counts().sort_index()
# Out:
# grade
# A    433027
# B    663557
# C    650053
# D    324424
# E    135639
# F     41800
# G     12168
# Name: count, dtype: int64

# %% [markdown]
# default status by grade

# %%
pd.crosstab(
 df["grade"],
 df["default_status"],
    normalize="index"
) * 100
# Out:
# default_status  Defaulted  Did Not Default  Outcome Unknown
# grade
# A                3.181326        49.088625        47.730049
# B                7.711169        49.633114        42.655718
# C               12.832646        44.172860        42.994494
# D               18.385200        42.023093        39.591707
# E               26.191582        41.716615        32.091803
# F               34.349282        41.564593        24.086124
# G               37.426036        37.730112        24.843853

# %% [markdown]
# Loan purpose EDA

# %%
df["purpose"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["purpose"].value_counts()
# Out:
# purpose
# debt_consolidation    1277877
# credit_card            516971
# home_improvement       150457
# other                  139440
# major_purchase          50445
# medical                 27488
# small_business          24689
# car                     24013
# vacation                15525
# moving                  15403
# house                   14136
# wedding                  2355
# renewable_energy         1445
# educational               424
# Name: count, dtype: int64

# %%
pd.crosstab(
    df["purpose"],
    df["default_status"],
    normalize="index"
) * 100
# Out:
# default_status      Defaulted  Did Not Default  Outcome Unknown
# purpose
# car                  8.666139        50.406030        40.927831
# credit_card          9.423933        45.907604        44.668463
# debt_consolidation  12.626411        46.746283        40.627306
# educational         20.754717        79.009434         0.235849
# home_improvement    10.074639        46.227826        43.697535
# house               10.780985        38.815789        50.403226
# major_purchase      10.560016        45.840024        43.599960
# medical             12.056170        42.811409        45.132421
# moving              14.062196        45.789781        40.148023
# other               11.465863        42.579604        45.954532
# renewable_energy    15.017301        48.235294        36.747405
# small_business      18.376605        43.071813        38.551582
# vacation            10.859903        45.507246        43.632850
# wedding             12.399151        87.388535         0.212314

# %%
df["application_type"].value_counts()
# Out:
# application_type
# Individual    2139958
# Joint App      120710
# Name: count, dtype: int64

# %%
df["is_joint_application"].value_counts()
# Out:
# is_joint_application
# 0    2139958
# 1     120710
# Name: count, dtype: int64

# %%
df[["issue_d", "loan_amnt"]].tail(200)
# Out:
#           issue_d  loan_amnt
# 2260468  Oct-2017      16650
# 2260469  Oct-2017       5000
# 2260470  Oct-2017      11550
# 2260471  Oct-2017      35000
# 2260472  Oct-2017       7000
# ...           ...        ...
# 2260663  Oct-2017      12000
# 2260664  Oct-2017      12000
# 2260665  Oct-2017      10000
# 2260666  Oct-2017      12000
# 2260667  Oct-2017      16550
#
# [200 rows x 2 columns]

# %%
df['issue_d'].value_counts()
# Out:
# issue_d
# Mar-2016    61992
# Oct-2015    48631
# May-2018    46311
# Oct-2018    46305
# Aug-2018    46079
#             ...
# Aug-2007       74
# Jul-2007       63
# Sep-2008       57
# Sep-2007       53
# Jun-2007       24
# Name: count, Length: 139, dtype: int64

# %%
# Look at the highest DTI values
df["dti"].sort_values(ascending=False).head(30)
# Out:
# 393830     999.0
# 429571     999.0
# 1630106    999.0
# 318578     999.0
# 125141     999.0
# 316296     999.0
# 2216420    999.0
# 10817      999.0
# 1455942    999.0
# 93645      999.0
# 418369     999.0
# 2255565    999.0
# 232376     999.0
# 2257269    999.0
# 193546     999.0
# 434895     999.0
# 140659     999.0
# 1527957    999.0
# 282750     999.0
# 441954     999.0
# 2245021    999.0
# 181195     999.0
# 180570     999.0
# 443800     999.0
# 202297     999.0
# 2173192    999.0
# 119299     999.0
# 1482359    999.0
# 626147     999.0
# 144660     999.0
# Name: dti, dtype: float64

# %%
df["dti"].value_counts(bins=[0, 10, 20, 30, 40, 50, 100, 200, 500, 800, 1000])
# Out:
# (10.0, 20.0]       922666
# (20.0, 30.0]       682257
# (-0.001, 10.0]     408634
# (30.0, 40.0]       218220
# (40.0, 50.0]        13439
# (50.0, 100.0]       11178
# (100.0, 200.0]       1725
# (200.0, 500.0]        572
# (800.0, 1000.0]       158
# (500.0, 800.0]        106
# Name: count, dtype: int64

# %%
df[df["dti"] > 100][["dti", "annual_inc", "loan_amnt", "loan_status"]].sort_values(
    "dti", ascending=False
).head(30)
# Out:
#            dti  annual_inc  loan_amnt         loan_status
# 2255565  999.0      1000.0      18000             Current
# 2257269  999.0      1200.0      30000             Current
# 2250157  999.0      1000.0      30000             Current
# 2249517  999.0        25.0      20000             Current
# 113177   999.0       500.0       9600             Current
# 10817    999.0       100.0       4750             Current
# 144660   999.0      1780.0      15000             Current
# 167599   999.0       100.0      24000             Current
# 2173192  999.0      1500.0      40000             Current
# 2162249  999.0       100.0      26000  Late (31-120 days)
# 2179408  999.0        20.0       5000         Charged Off
# 2176576  999.0      2000.0      35000             Current
# 1630106  999.0      1000.0      35000          Fully Paid
# 1635578  999.0      1000.0      19500             Current
# 2186663  999.0      1000.0      24000             Current
# ...
